# %% [markdown]
# <a href="https://colab.research.google.com/github/Monique0110604/Monique0110604/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 🧠 1. Sistema de Acesso ao Laboratório

### 🟢 Básico
Um aluno só pode entrar no laboratório se:
- tiver idade ≥ 16
- E tiver autorização (S/N)

👉 Mostre se ele pode entrar ou não.

### 🟡 Médio
Regras:
- Se for menor de 18, precisa obrigatoriamente de autorização
- Se for maior ou igual a 18, pode entrar sem autorização

👉 Exiba:
- "Entrada permitida com autorização"
- "Entrada permitida"
- "Entrada negada"
### 🔴 Alto
Adicione:
- Se for após 22h, ninguém pode entrar
- Receba também a hora atual

👉 Priorize corretamente as regras.

---

## 🎮 2. Sistema de Pontuação de Jogo
O usuário informa qual é sua pontuação.
### 🟢 Básico
Receba a pontuação:
- ≥ 100 → "Nível Avançado"
- < 100 → "Nível Iniciante"

---

### 🟡 Médio
- ≥ 200 → "Elite"
- 100 a 199 → "Intermediário"
- < 100 → "Iniciante"

---

### 🔴 Alto
Adicione:
- Pontuação negativa → "Erro: pontuação inválida"
- Pontuação == 150 → "Bônus especial!"

---

## 🛒 3. Sistema de Compra com Desconto
O usuário informa o valor e a quantidade de 5 produtos, calcule o valor final e aplique desconto.
Identifique que tipo o cliente é: básico(sem desconto) ou vip
### 🟢 Básico
- ≥ 100 → 10% de desconto
- < 100 → sem desconto

---

### 🟡 Médio
- ≥ 200 → 20%
- 100 a 199 → 10%
- < 100 → 0%

---

### 🔴 Alto
Adicione:
- Cliente VIP (S/N) ganha +5% de desconto
- Mostrar valor final com desconto

---

## 🌡️ 4. Monitoramento de Temperatura
Usuário informa a temperatura do servidor:
### 🟢 Básico
- ≥ 70 → "Alerta"
- < 70 → "Normal"

---

### 🟡 Médio
- ≥ 90 → "CRÍTICO"
- 70 a 89 → "Alerta"
- < 70 → "Normal"

---

### 🔴 Alto
Adicione:
- Temperatura < 0 → "Sensor com erro"
- Se crítico → "Desligar servidor imediatamente"

---

## 🏫 5. Avaliação de Projeto
O usuario informa a nota que seu projeto recebeu:
### 🟢 Básico
- ≥ 7 → "Aprovado"
- < 7 → "Reprovado"

---

### 🟡 Médio
- ≥ 9 → "Aprovado com excelência"
- 7 a 8.9 → "Aprovado"
- < 7 → "Reprovado"

---

### 🔴 Alto
Adicione:
- Nota > 10 ou < 0 → "Nota inválida"
- Nota == 10 → "Projeto destaque da turma 🏆"

---

# 🚀 Desafio Extra

💡 Escolha um dos exercícios acima e implemente:
- Uma versão simples
- Uma versão completa (nível alto)

🎯 Compare as duas soluções e identifique:
- O que mudou na lógica?
- Quais condições foram adicionadas?

---

# 👩‍💻 Dica

Não existe apenas uma forma correta de resolver os exercícios.
O mais importante é **entender a lógica por trás das decisões**.

# %%
#exer1 médio/alto

idade = int(input("Idade: "))
aut = input("Tem autorizaçao? (sim/nao): ")
hora = int(input("Hora atual: (0-23): "))

if hora > 22:
  print("Entrada negada")
elif idade > 18:
  print("Entrada permitida")
elif idade < 16 and aut == "sim":
  print("Entrada permitida com autorizaçao")
else:
  print("Entrada negada")
# Out:
# Idade: 19
# Tem autorizaçao? (sim/nao): sim
# Hora atual: (0-23): 23
# Entrada negada

# %%
#exer1 básico

idade = int(input("Idade: "))
aut = input("Tem autorizacao? (sim/nao): ")

if idade > 16:
  print('Entrada permitida')
elif idade > 16:
  print("Tem autorizacao")
else:
  print("Entrada negada")
# Out:
# Idade: 18
# Tem autorizacao? (sim/nao): sim
# Entrada permitida

# %%
#exer2 básico

pontos = int(input("Pontuacao: "))

if pontos > 100:
  print("Nivel avancado")
elif pontos < 100:
  print("Nivel iniciante")
# Out:
# Pontuacao: 134
# Nivel avancado

# %%
#exer2 medio/alto

pontos=int(input("Pontuacao: "))

if pontos > 200:
  print("Elite")
elif pontos in range (100,199):
  print("Intermediario")
elif pontos < 100:
  print("Iniciante")
# Out:
# Pontuacao: 130
# Intermediario

# %%
#exer2 medio/alto

pontos=int(input("Pontuacao: "))

if pontos > 200:
  print("Elite")
elif pontos >= 100 and pontos <=199:
  if pontos == 150:
     print("Bonus especial!")
  print("Intermediario")
elif pontos < 100 and pontos >0:
  print("Iniciante")
elif pontos <0:
  print("Erro:pontuacao invalida")
# Out:
# Pontuacao: 155
# Intermediario
